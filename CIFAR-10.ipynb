# %%
import tensorflow as tf 

(x_train  , y_train) , (x_test , y_test)  = tf.keras.datasets.cifar10.load_data()
x_train = x_train /255 ; x_test = x_test/255

data_generator = tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip = True,
                                                                 zoom_range = 0.05,
                                                                 width_shift_range = 0.05 ,
                                                                 height_shift_range = 0.05)
train_generator = data_generator.flow(x_train,
                                      y_train,
                                      batch_size = 32)

base_model = tf.keras.applications.ResNet50V2(include_top = False,
                                              weights = "imagenet",
                                              input_shape = x_train.shape[1:] , 
                                              classes = 10)
model= tf.keras.Sequential()
model.add(base_model) 
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1024,activation=('relu'))) 
model.add(tf.keras.layers.Dropout(.2))
model.add(tf.keras.layers.Dense(10,activation=('softmax')))

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0005),
              loss = "sparse_categorical_crossentropy",
              metrics = ["accuracy"])

history = model.fit(train_generator , 
                    validation_data=(x_test , y_test), 
                    steps_per_epoch = x_train.shape[0]/32,
                    epochs=20 ,
                    verbose = 1 )

model.save("CIFAR-10.h5")
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 1562.5 steps, validate on 10000 samples
# Epoch 1/20
# 1563/1562 [==============================] - 113s 73ms/step - loss: 1.5749 - accuracy: 0.4642 - val_loss: 1.4440 - val_accuracy: 0.56360 - accuracy: 0.45 - ETA: 8s - los - ETA: 7s - loss: 1.5936 - accuracy: 0.45 - ETA: 7s - loss: 1.5938 -  - E - ETA: 3s - loss: 1.5838
# Epoch 2/20
# 1563/1562 [==============================] - 99s 64ms/step - loss: 1.2989 - accuracy: 0.5570 - val_loss: 1.7310 - val_accuracy: 0.4013
# Epoch 3/20
# 1563/1562 [==============================] - 99s 63ms/step - loss: 1.4008 - accuracy: 0.5098 - val_loss: 1.3354 - val_accuracy: 0.5409
# Epoch 4/20
# 1563/1562 [==============================] - 99s 64ms/step - loss: 1.2369 - accuracy: 0.5716 - val_loss: 1.3803 - val_accuracy: 0.5082
# Epoch 5/20
# 1563/1562 [==============================] - 102s 65ms/step - loss: 1.2243 - accuracy: 0.5781 - val_loss: 1.2464 - val_accuracy: 0.6112
# Epoch 6/20
# 1563/1562 [==============================] - 101s 64ms/step - loss: 1.1977 - accuracy: 0.5853 - val_loss: 1.5742 - val_accuracy: 0.4868 - ETA: 0s - loss: 1.1976 - accura
# Epoch 7/20
# 1563/1562 [==============================] - 100s 64ms/step - loss: 1.2981 - accuracy: 0.5491 - val_loss: 1.0459 - val_accuracy: 0.6398lo - ETA: 36 - ETA: 23s - loss: 1.3320 - a
# Epoch 8/20
# 1563/1562 [==============================] - 99s 64ms/step - loss: 1.1682 - accuracy: 0.5972 - val_loss: 1.6548 - val_accuracy: 0.4388
# Epoch 9/20
# 1563/1562 [==============================] - 100s 64ms/step - loss: 1.1216 - accuracy: 0.6187 - val_loss: 2.0864 - val_accuracy: 0.4285
# Epoch 10/20
# 1563/1562 [==============================] - 100s 64ms/step - loss: 0.9952 - accuracy: 0.6658 - val_loss: 0.9765 - val_accuracy: 0.6832
# Epoch 11/20
# 1563/1562 [==============================] - 99s 63ms/step - loss: 0.8871 - accuracy: 0.6992 - val_loss: 1.1541 - val_accuracy: 0.6004
# Epoch 12/20
# 1563/1562 [==============================] - 99s 63ms/step - loss: 0.8034 - accuracy: 0.7299 - val_loss: 0.8964 - val_accuracy: 0.6979
# Epoch 13/20
# 1563/1562 [==============================] - 100s 64ms/step - loss: 0.7509 - accuracy: 0.7478 - val_loss: 0.8152 - val_accuracy: 0.7204
# Epoch 14/20
# 1563/1562 [==============================] - 100s 64ms/step - loss: 0.6942 - accuracy: 0.7642 - val_loss: 0.7498 - val_accuracy: 0.7450 - accuracy: 0.7 - ETA: 19s - loss: 0.6915 - accuracy: - ETA: 1
# Epoch 15/20
# 1563/1562 [==============================] - 100s 64ms/step - loss: 0.6516 - accuracy: 0.7787 - val_loss: 0.8748 - val_accuracy: 0.7143
# Epoch 16/20
# 1563/1562 [==============================] - 100s 64ms/step - loss: 0.6094 - accuracy: 0.7942 - val_loss: 0.7959 - val_accuracy: 0.7408
# Epoch 17/20
# 1563/1562 [==============================] - 99s 64ms/step - loss: 0.5798 - accuracy: 0.8066 - val_loss: 0.7224 - val_accuracy: 0.7632
# Epoch 18/20
# 1563/1562 [==============================] - 100s 64ms/step - loss: 0.5528 - accuracy: 0.8153 - val_loss: 0.6719 - val_accuracy: 0.7815 ETA: 21s - loss: 0.5517 - accuracy: 0.81 - ETA: - ETA: 19s - loss:  - ETA: 17s - - ETA: 15s - loss: 0.5537 - accur  - ETA: 0s - loss: 0
# Epoch 19/20
# 1563/1562 [==============================] - 100s 64ms/step - loss: 0.5233 - accuracy: 0.8233 - val_loss: 0.8309 - val_accuracy: 0.7351
# Epoch 20/20
# 1563/1562 [==============================] - 99s 63ms/step - loss: 0.4924 - accuracy: 0.8332 - val_loss: 0.6724 - val_accuracy: 0.7785
